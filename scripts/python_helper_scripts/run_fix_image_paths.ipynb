# %%
from fix_image_paths import ImagePathFixer
import os


# Set up Google Cloud credentials for uv environment - use expanduser to properly resolve the path
os.environ['GOOGLE_APPLICATION_CREDENTIALS'] = os.path.expanduser('~/.config/gcloud/application_default_credentials.json')


# Create and run the fixer
fixer = ImagePathFixer(
    project_id="wilde-rosen-483d1",
    bucket_name="wilde-rosen-483d1.firebasestorage.app",
    dry_run=False
)

fixer.run()
