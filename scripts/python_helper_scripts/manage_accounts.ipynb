# %% [markdown]
# # Manage Accounts

# %%
import json
from account_manager import AccountManager

manager = AccountManager()

# %%
search_strings = []
search_res = manager.search_accounts(search_strings)
print(json.dumps(search_res, indent=2))

# %%
merge_res = manager.merge_accounts(
    primary_account_id='',
    secondary_account_id='',
    name=''
)
print(json.dumps(merge_res, indent=2))
