# %%
from firebase_util import FirestoreCopyUtil
from env import PRD_PROJECT_ID, NPR_PROJECT_ID

# Set your project IDs from env file
SOURCE_PROJECT_ID = PRD_PROJECT_ID  # Production as source
DEST_PROJECT_ID = NPR_PROJECT_ID    # NPR as destination

copier = FirestoreCopyUtil(SOURCE_PROJECT_ID, DEST_PROJECT_ID)

# %%
# List of document paths to copy
docs_to_copy = [
    # "cars/kangoo/damages/AAss1HaFcfgKAI7WHkTs", 
    "cars/kangoo/damages/FbBr40IWUPgVCREUEtEs",  
    # Add more as needed
]

# Create the util object

# Copy documents
copier.copy_documents(docs_to_copy)

# Verify documents
copier.verify_documents(docs_to_copy)
